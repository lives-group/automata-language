# %%
#lang iracket/lang #:require racket
(require "re.rkt" "re-to-dfa.rkt" "../dfa/automaton-correction.rkt" "../dfa/image-builder.rkt" "../dfa/core.rkt" "../fa.rkt")

# %% [markdown]
# #### Questão 1

# %% [markdown]
# Crie um AFD equivalente a seguinte expressão regular: ((1 + λ)(1)* + (1(0 + λ))*)

# %%
(define resposta1
    null
)

# %%
(automaton-correction resposta1 ((compose car dfa-rename-states re-sigma-to-dfa) (list #\0 #\1) (UNION (KLEENE-CLOSURE (CONCATENATION (CONCATENATION (SYMBOL #\1) (LAMBDA)) (UNION (LAMBDA) (SYMBOL #\0)))) (CONCATENATION (UNION (CONCATENATION (LAMBDA) (LAMBDA)) (INTERSECTION (SYMBOL #\1) (SYMBOL #\1))) (KLEENE-CLOSURE (KLEENE-CLOSURE (SYMBOL #\1)))))))

# %% [markdown]
# #### Questão 2

# %% [markdown]
# Crie um AFD equivalente a seguinte expressão regular: (¬((0 + 1)))*

# %%
(define resposta2
    null
)

# %%
(automaton-correction resposta2 ((compose car dfa-rename-states re-sigma-to-dfa) (list #\0 #\1) (KLEENE-CLOSURE (KLEENE-CLOSURE (COMPLEMENT (UNION (SYMBOL #\1) (SYMBOL #\0)))))))

# %% [markdown]
# #### Questão 3

# %% [markdown]
# Crie um AFD equivalente a seguinte expressão regular: ((1 + ¬(λ)01 + (0)\*))*

# %%
(define resposta3
    null
)

# %%
(automaton-correction resposta3 ((compose car dfa-rename-states re-sigma-to-dfa) (list #\0 #\1) (KLEENE-CLOSURE (UNION (UNION (KLEENE-CLOSURE (SYMBOL #\0)) (UNION (SYMBOL #\1) (LAMBDA))) (CONCATENATION (COMPLEMENT (LAMBDA)) (CONCATENATION (SYMBOL #\0) (SYMBOL #\1)))))))

# %% [markdown]
# #### Questão 4

# %% [markdown]
# Crie um AFD equivalente a seguinte expressão regular: ¬((1 + (11 & 10) + (0)*))

# %%
(define resposta4
    null
)

# %%
(automaton-correction resposta4 ((compose car dfa-rename-states re-sigma-to-dfa) (list #\0 #\1) (COMPLEMENT (UNION (INTERSECTION (CONCATENATION (SYMBOL #\1) (SYMBOL #\1)) (CONCATENATION (SYMBOL #\1) (SYMBOL #\0))) (UNION (UNION (LAMBDA) (SYMBOL #\1)) (KLEENE-CLOSURE (SYMBOL #\0)))))))

# %% [markdown]
# #### Questão 5

# %% [markdown]
# Crie um AFD equivalente a seguinte expressão regular: (01¬(1))\*(11 + λ)(0)*

# %%
(define resposta5
    null
)

# %%
(automaton-correction resposta5 ((compose car dfa-rename-states re-sigma-to-dfa) (list #\0 #\1) (CONCATENATION (KLEENE-CLOSURE (CONCATENATION (CONCATENATION (SYMBOL #\0) (SYMBOL #\1)) (COMPLEMENT (SYMBOL #\1)))) (CONCATENATION (UNION (CONCATENATION (SYMBOL #\1) (SYMBOL #\1)) (UNION (LAMBDA) (LAMBDA))) (CONCATENATION (KLEENE-CLOSURE (SYMBOL #\0)) (KLEENE-CLOSURE (LAMBDA)))))))

# %% [markdown]
# #### Questão 6

# %% [markdown]
# Crie um AFD equivalente a seguinte expressão regular: ((0)\*(0 + 1)000 + (¬(1)0)\*)

# %%
(define resposta6
    null
)

# %%
(automaton-correction resposta6 ((compose car dfa-rename-states re-sigma-to-dfa) (list #\0 #\1) (UNION (CONCATENATION (CONCATENATION (KLEENE-CLOSURE (SYMBOL #\0)) (UNION (SYMBOL #\0) (SYMBOL #\1))) (CONCATENATION (CONCATENATION (SYMBOL #\0) (LAMBDA)) (CONCATENATION (SYMBOL #\0) (SYMBOL #\0)))) (KLEENE-CLOSURE (CONCATENATION (COMPLEMENT (SYMBOL #\1)) (UNION (SYMBOL #\0) (SYMBOL #\0)))))))

# %% [markdown]
# #### Questão 7

# %% [markdown]
# Crie um AFD equivalente a seguinte expressão regular: ((0)* & ((0 + λ))\*)((1 + λ))*

# %%
(define resposta7
    null
)

# %%
(automaton-correction resposta7 ((compose car dfa-rename-states re-sigma-to-dfa) (list #\0 #\1) (CONCATENATION (INTERSECTION (KLEENE-CLOSURE (UNION (SYMBOL #\0) (SYMBOL #\0))) (KLEENE-CLOSURE (UNION (SYMBOL #\0) (LAMBDA)))) (KLEENE-CLOSURE (UNION (CONCATENATION (LAMBDA) (LAMBDA)) (UNION (LAMBDA) (SYMBOL #\1)))))))

# %% [markdown]
# #### Questão 8

# %% [markdown]
# Crie um AFD equivalente a seguinte expressão regular: λ

# %%
(define resposta8
    null
)

# %%
(automaton-correction resposta8 ((compose car dfa-rename-states re-sigma-to-dfa) (list #\0 #\1) (UNION (KLEENE-CLOSURE (KLEENE-CLOSURE (INTERSECTION (SYMBOL #\1) (LAMBDA)))) (INTERSECTION (KLEENE-CLOSURE (KLEENE-CLOSURE (LAMBDA))) (UNION (UNION (LAMBDA) (LAMBDA)) (KLEENE-CLOSURE (SYMBOL #\1)))))))

# %% [markdown]
# #### Questão 9

# %% [markdown]
# Crie um AFD equivalente a seguinte expressão regular: ((1)* & ((0 + 1))\*)(0 + (1)*)

# %%
(define resposta9
    null
)

# %%
(automaton-correction resposta9 ((compose car dfa-rename-states re-sigma-to-dfa) (list #\0 #\1) (CONCATENATION (INTERSECTION (KLEENE-CLOSURE (UNION (SYMBOL #\0) (SYMBOL #\1))) (CONCATENATION (KLEENE-CLOSURE (LAMBDA)) (KLEENE-CLOSURE (SYMBOL #\1)))) (UNION (UNION (KLEENE-CLOSURE (SYMBOL #\1)) (CONCATENATION (LAMBDA) (SYMBOL #\0))) (UNION (CONCATENATION (LAMBDA) (LAMBDA)) (UNION (LAMBDA) (LAMBDA)))))))

# %% [markdown]
# #### Questão 10

# %% [markdown]
# Crie um AFD equivalente a seguinte expressão regular: (0 + 00 + 1(0 + λ) + λ)(1(0)* + (1)*(1 + λ))

# %%
(define resposta10
    null
)

# %%
(automaton-correction resposta10 ((compose car dfa-rename-states re-sigma-to-dfa) (list #\0 #\1) (CONCATENATION (UNION (CONCATENATION (CONCATENATION (SYMBOL #\1) (LAMBDA)) (UNION (LAMBDA) (SYMBOL #\0))) (UNION (CONCATENATION (SYMBOL #\0) (SYMBOL #\0)) (UNION (LAMBDA) (SYMBOL #\0)))) (UNION (CONCATENATION (KLEENE-CLOSURE (SYMBOL #\1)) (UNION (LAMBDA) (SYMBOL #\1))) (CONCATENATION (CONCATENATION (LAMBDA) (SYMBOL #\1)) (KLEENE-CLOSURE (SYMBOL #\0)))))))
