# %%
#lang iracket/lang #:require racket
(require "grammar.rkt" "grammar-to-nfa.rkt" "../nfa/subset-construction.rkt" "../dfa/automaton-correction.rkt" "../dfa/image-builder.rkt")

# %% [markdown]
# #### Questão 1

# %% [markdown]
# Crie uma gramática equivalente ao seguinte AFD:

# %%
((compose dfa->pict nfa->dfa grammar->nfa) (grammar '(V0 V1) '(|0| |1|) (list (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "0")) (list (VARIABLE "V1") (SYMBOL "1")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V0")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V0")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V0"))) 'V0))
# Out:
# (pict '(prog #<procedure:...t/private/utils.rkt:1193:6> 170) 380 170 170 0 '() #f #f)

# %%
(define resposta1
    (grammar
   '(S A B)    ;; variables
   '(|0| |1|)  ;; alphabet
   (list
    (cons (VARIABLE "S") (list (SYMBOL "0") (VARIABLE "B")))
    (cons (VARIABLE "S") (list (SYMBOL "1") (VARIABLE "A")))
    (cons (VARIABLE "A") (list (SYMBOL "0") (VARIABLE "S")))
    (cons (VARIABLE "A") (list (SYMBOL "1") (VARIABLE "B")))
    (cons (VARIABLE "B") (list (SYMBOL "0") (VARIABLE "B")))
    (cons (VARIABLE "B") (list (SYMBOL "1") (VARIABLE "A")))
    (cons (VARIABLE "A") (list (LAMBDA))))
   'S)
)

# %%
(automaton-correction ((compose nfa->dfa grammar->nfa) resposta1) ((compose nfa->dfa grammar->nfa) (grammar '(V0 V1) '(|0| |1|) (list (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "0")) (list (VARIABLE "V1") (SYMBOL "1")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V0")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V0")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V0"))) 'V0)))
# Out:
# Your automaton is accepting a word(s) that it should not: (1)
# Your automaton is not accepting word(s) that it should: (010 0)

# %% [markdown]
# #### Questão 2

# %% [markdown]
# Crie uma gramática equivalente ao seguinte AFD:

# %%
((compose dfa->pict nfa->dfa grammar->nfa) (grammar '(V0 V1) '(|0| |1|) (list (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "0")) (list (VARIABLE "V1") (SYMBOL "1")) (list (VARIABLE "V1") (LAMBDA)) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V0")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V0")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V0")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V0"))) 'V0))
# Out:
# (pict '(prog #<procedure:...t/private/utils.rkt:1193:6> 187) 391 187 187 0 '() #f #f)

# %%
(define resposta2
    null
)

# %%
(automaton-correction ((compose nfa->dfa grammar->nfa) resposta2) ((compose nfa->dfa grammar->nfa) (grammar '(V0 V1) '(|0| |1|) (list (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "0")) (list (VARIABLE "V1") (SYMBOL "1")) (list (VARIABLE "V1") (LAMBDA)) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V0")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V0")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V0")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V0"))) 'V0)))

# %% [markdown]
# #### Questão 3

# %% [markdown]
# Crie uma gramática equivalente ao seguinte AFD:

# %%
((compose dfa->pict nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3) '(|0| |1|) (list (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "0")) (list (VARIABLE "V1") (SYMBOL "0")) (list (VARIABLE "V2") (SYMBOL "1")) (list (VARIABLE "V3") (SYMBOL "1")) (list (VARIABLE "V1") (LAMBDA)) (list (VARIABLE "V3") (LAMBDA))) 'V0))
# Out:
# (pict '(prog #<procedure:...t/private/utils.rkt:1193:6> 214) 645 214 214 0 '() #f #f)

# %%
(define resposta3
    null
)

# %%
(automaton-correction ((compose nfa->dfa grammar->nfa) resposta3) ((compose nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3) '(|0| |1|) (list (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "0")) (list (VARIABLE "V1") (SYMBOL "0")) (list (VARIABLE "V2") (SYMBOL "1")) (list (VARIABLE "V3") (SYMBOL "1")) (list (VARIABLE "V1") (LAMBDA)) (list (VARIABLE "V3") (LAMBDA))) 'V0)))

# %% [markdown]
# #### Questão 4

# %% [markdown]
# Crie uma gramática equivalente ao seguinte AFD:

# %%
((compose dfa->pict nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3 V4 V5) '(|0| |1|) (list (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V5")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V4")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V3")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "1")) (list (VARIABLE "V1") (SYMBOL "1")) (list (VARIABLE "V2") (SYMBOL "0")) (list (VARIABLE "V3") (SYMBOL "1")) (list (VARIABLE "V4") (SYMBOL "0")) (list (VARIABLE "V5") (SYMBOL "0")) (list (VARIABLE "V2") (LAMBDA)) (list (VARIABLE "V3") (LAMBDA)) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V5") (SYMBOL "1") (VARIABLE "V0")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V2") (SYMBOL "1") (VARIABLE "V0")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V5")) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V4")) (list (VARIABLE "V3") (SYMBOL "0") (VARIABLE "V4")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V4") (SYMBOL "0") (VARIABLE "V0")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V5") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V4") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V0")) (list (VARIABLE "V4") (SYMBOL "1") (VARIABLE "V2"))) 'V0))
# Out:
# (pict '(prog #<procedure:...t/private/utils.rkt:1193:6> 244) 816 244 244 0 '() #f #f)

# %%
(define resposta4
    null
)

# %%
(automaton-correction ((compose nfa->dfa grammar->nfa) resposta4) ((compose nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3 V4 V5) '(|0| |1|) (list (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V5")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V4")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V3")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "1")) (list (VARIABLE "V1") (SYMBOL "1")) (list (VARIABLE "V2") (SYMBOL "0")) (list (VARIABLE "V3") (SYMBOL "1")) (list (VARIABLE "V4") (SYMBOL "0")) (list (VARIABLE "V5") (SYMBOL "0")) (list (VARIABLE "V2") (LAMBDA)) (list (VARIABLE "V3") (LAMBDA)) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V5") (SYMBOL "1") (VARIABLE "V0")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V2") (SYMBOL "1") (VARIABLE "V0")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V5")) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V4")) (list (VARIABLE "V3") (SYMBOL "0") (VARIABLE "V4")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V4") (SYMBOL "0") (VARIABLE "V0")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V5") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V4") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V0")) (list (VARIABLE "V4") (SYMBOL "1") (VARIABLE "V2"))) 'V0)))

# %% [markdown]
# #### Questão 5

# %% [markdown]
# Crie uma gramática equivalente ao seguinte AFD:

# %%
((compose dfa->pict nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3 V4) '(|0| |1|) (list (list (VARIABLE "V3") (SYMBOL "1") (VARIABLE "V4")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V3")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "0")) (list (VARIABLE "V1") (SYMBOL "0")) (list (VARIABLE "V2") (SYMBOL "0")) (list (VARIABLE "V3") (SYMBOL "0")) (list (VARIABLE "V4") (SYMBOL "1")) (list (VARIABLE "V0") (LAMBDA)) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V3") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V4") (SYMBOL "1") (VARIABLE "V3")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V2"))) 'V0))
# Out:
# (pict '(prog #<procedure:...t/private/utils.rkt:1193:6> 387) 645 387 387 0 '() #f #f)

# %%
(define resposta5
    null
)

# %%
(automaton-correction ((compose nfa->dfa grammar->nfa) resposta5) ((compose nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3 V4) '(|0| |1|) (list (list (VARIABLE "V3") (SYMBOL "1") (VARIABLE "V4")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V3")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "0")) (list (VARIABLE "V1") (SYMBOL "0")) (list (VARIABLE "V2") (SYMBOL "0")) (list (VARIABLE "V3") (SYMBOL "0")) (list (VARIABLE "V4") (SYMBOL "1")) (list (VARIABLE "V0") (LAMBDA)) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V3") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V4") (SYMBOL "1") (VARIABLE "V3")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V2"))) 'V0)))

# %% [markdown]
# #### Questão 6

# %% [markdown]
# Crie uma gramática equivalente ao seguinte AFD:

# %%
((compose dfa->pict nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3 V4 V5 V6) '(|0| |1|) (list (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V6")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V5")) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V4")) (list (VARIABLE "V2") (SYMBOL "1") (VARIABLE "V3")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "1")) (list (VARIABLE "V1") (SYMBOL "1")) (list (VARIABLE "V2") (SYMBOL "1")) (list (VARIABLE "V3") (SYMBOL "0")) (list (VARIABLE "V4") (SYMBOL "1")) (list (VARIABLE "V5") (SYMBOL "1")) (list (VARIABLE "V6") (SYMBOL "1"))) 'V0))
# Out:
# (pict '(prog #<procedure:...t/private/utils.rkt:1193:6> 321) 645 321 321 0 '() #f #f)

# %%
(define resposta6
    null
)

# %%
(automaton-correction ((compose nfa->dfa grammar->nfa) resposta6) ((compose nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3 V4 V5 V6) '(|0| |1|) (list (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V6")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V5")) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V4")) (list (VARIABLE "V2") (SYMBOL "1") (VARIABLE "V3")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "1")) (list (VARIABLE "V1") (SYMBOL "1")) (list (VARIABLE "V2") (SYMBOL "1")) (list (VARIABLE "V3") (SYMBOL "0")) (list (VARIABLE "V4") (SYMBOL "1")) (list (VARIABLE "V5") (SYMBOL "1")) (list (VARIABLE "V6") (SYMBOL "1"))) 'V0)))

# %% [markdown]
# #### Questão 7

# %% [markdown]
# Crie uma gramática equivalente ao seguinte AFD:

# %%
((compose dfa->pict nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3 V4 V5 V6 V7 V8 V9 V10 V11) '(|0| |1|) (list (list (VARIABLE "V5") (SYMBOL "0") (VARIABLE "V11")) (list (VARIABLE "V9") (SYMBOL "1") (VARIABLE "V10")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V9")) (list (VARIABLE "V4") (SYMBOL "1") (VARIABLE "V8")) (list (VARIABLE "V5") (SYMBOL "0") (VARIABLE "V7")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V6")) (list (VARIABLE "V4") (SYMBOL "0") (VARIABLE "V5")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V4")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "1")) (list (VARIABLE "V1") (SYMBOL "0")) (list (VARIABLE "V2") (SYMBOL "1")) (list (VARIABLE "V3") (SYMBOL "0")) (list (VARIABLE "V4") (SYMBOL "0")) (list (VARIABLE "V5") (SYMBOL "1")) (list (VARIABLE "V6") (SYMBOL "0")) (list (VARIABLE "V7") (SYMBOL "1")) (list (VARIABLE "V8") (SYMBOL "1")) (list (VARIABLE "V9") (SYMBOL "1")) (list (VARIABLE "V10") (SYMBOL "0")) (list (VARIABLE "V11") (SYMBOL "1")) (list (VARIABLE "V1") (LAMBDA)) (list (VARIABLE "V3") (LAMBDA)) (list (VARIABLE "V4") (LAMBDA)) (list (VARIABLE "V9") (LAMBDA)) (list (VARIABLE "V8") (SYMBOL "1") (VARIABLE "V11")) (list (VARIABLE "V9") (SYMBOL "1") (VARIABLE "V11")) (list (VARIABLE "V9") (SYMBOL "0") (VARIABLE "V10")) (list (VARIABLE "V6") (SYMBOL "0") (VARIABLE "V5"))) 'V0))
# Out:
# (pict '(prog #<procedure:...t/private/utils.rkt:1193:6> 534) 794 534 534 0 '() #f #f)

# %%
(define resposta7
    null
)

# %%
(automaton-correction ((compose nfa->dfa grammar->nfa) resposta7) ((compose nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3 V4 V5 V6 V7 V8 V9 V10 V11) '(|0| |1|) (list (list (VARIABLE "V5") (SYMBOL "0") (VARIABLE "V11")) (list (VARIABLE "V9") (SYMBOL "1") (VARIABLE "V10")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V9")) (list (VARIABLE "V4") (SYMBOL "1") (VARIABLE "V8")) (list (VARIABLE "V5") (SYMBOL "0") (VARIABLE "V7")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V6")) (list (VARIABLE "V4") (SYMBOL "0") (VARIABLE "V5")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V4")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "1")) (list (VARIABLE "V1") (SYMBOL "0")) (list (VARIABLE "V2") (SYMBOL "1")) (list (VARIABLE "V3") (SYMBOL "0")) (list (VARIABLE "V4") (SYMBOL "0")) (list (VARIABLE "V5") (SYMBOL "1")) (list (VARIABLE "V6") (SYMBOL "0")) (list (VARIABLE "V7") (SYMBOL "1")) (list (VARIABLE "V8") (SYMBOL "1")) (list (VARIABLE "V9") (SYMBOL "1")) (list (VARIABLE "V10") (SYMBOL "0")) (list (VARIABLE "V11") (SYMBOL "1")) (list (VARIABLE "V1") (LAMBDA)) (list (VARIABLE "V3") (LAMBDA)) (list (VARIABLE "V4") (LAMBDA)) (list (VARIABLE "V9") (LAMBDA)) (list (VARIABLE "V8") (SYMBOL "1") (VARIABLE "V11")) (list (VARIABLE "V9") (SYMBOL "1") (VARIABLE "V11")) (list (VARIABLE "V9") (SYMBOL "0") (VARIABLE "V10")) (list (VARIABLE "V6") (SYMBOL "0") (VARIABLE "V5"))) 'V0)))

# %% [markdown]
# #### Questão 8

# %% [markdown]
# Crie uma gramática equivalente ao seguinte AFD:

# %%
((compose dfa->pict nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3 V4 V5 V6 V7 V8) '(|0| |1|) (list (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V8")) (list (VARIABLE "V4") (SYMBOL "0") (VARIABLE "V7")) (list (VARIABLE "V3") (SYMBOL "1") (VARIABLE "V6")) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V5")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V4")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "1")) (list (VARIABLE "V1") (SYMBOL "1")) (list (VARIABLE "V2") (SYMBOL "1")) (list (VARIABLE "V3") (SYMBOL "1")) (list (VARIABLE "V4") (SYMBOL "0")) (list (VARIABLE "V5") (SYMBOL "0")) (list (VARIABLE "V6") (SYMBOL "1")) (list (VARIABLE "V7") (SYMBOL "0")) (list (VARIABLE "V8") (SYMBOL "0")) (list (VARIABLE "V0") (LAMBDA)) (list (VARIABLE "V4") (LAMBDA)) (list (VARIABLE "V7") (LAMBDA)) (list (VARIABLE "V8") (LAMBDA)) (list (VARIABLE "V8") (SYMBOL "1") (VARIABLE "V2")) (list (VARIABLE "V3") (SYMBOL "1") (VARIABLE "V3")) (list (VARIABLE "V5") (SYMBOL "0") (VARIABLE "V0")) (list (VARIABLE "V4") (SYMBOL "0") (VARIABLE "V6")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V7")) (list (VARIABLE "V6") (SYMBOL "1") (VARIABLE "V5")) (list (VARIABLE "V3") (SYMBOL "1") (VARIABLE "V1"))) 'V0))
# Out:
# (pict '(prog #<procedure:...t/private/utils.rkt:1193:6> 276) 816 276 276 0 '() #f #f)

# %%
(define resposta8
    null
)

# %%
(automaton-correction ((compose nfa->dfa grammar->nfa) resposta8) ((compose nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3 V4 V5 V6 V7 V8) '(|0| |1|) (list (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V8")) (list (VARIABLE "V4") (SYMBOL "0") (VARIABLE "V7")) (list (VARIABLE "V3") (SYMBOL "1") (VARIABLE "V6")) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V5")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V4")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "1")) (list (VARIABLE "V1") (SYMBOL "1")) (list (VARIABLE "V2") (SYMBOL "1")) (list (VARIABLE "V3") (SYMBOL "1")) (list (VARIABLE "V4") (SYMBOL "0")) (list (VARIABLE "V5") (SYMBOL "0")) (list (VARIABLE "V6") (SYMBOL "1")) (list (VARIABLE "V7") (SYMBOL "0")) (list (VARIABLE "V8") (SYMBOL "0")) (list (VARIABLE "V0") (LAMBDA)) (list (VARIABLE "V4") (LAMBDA)) (list (VARIABLE "V7") (LAMBDA)) (list (VARIABLE "V8") (LAMBDA)) (list (VARIABLE "V8") (SYMBOL "1") (VARIABLE "V2")) (list (VARIABLE "V3") (SYMBOL "1") (VARIABLE "V3")) (list (VARIABLE "V5") (SYMBOL "0") (VARIABLE "V0")) (list (VARIABLE "V4") (SYMBOL "0") (VARIABLE "V6")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V7")) (list (VARIABLE "V6") (SYMBOL "1") (VARIABLE "V5")) (list (VARIABLE "V3") (SYMBOL "1") (VARIABLE "V1"))) 'V0)))

# %% [markdown]
# #### Questão 9

# %% [markdown]
# Crie uma gramática equivalente ao seguinte AFD:

# %%
((compose dfa->pict nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3 V4 V5 V6 V7 V8) '(|0| |1|) (list (list (VARIABLE "V3") (SYMBOL "0") (VARIABLE "V8")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V7")) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V6")) (list (VARIABLE "V4") (SYMBOL "0") (VARIABLE "V5")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V4")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V3")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "1")) (list (VARIABLE "V1") (SYMBOL "1")) (list (VARIABLE "V2") (SYMBOL "1")) (list (VARIABLE "V3") (SYMBOL "1")) (list (VARIABLE "V4") (SYMBOL "1")) (list (VARIABLE "V5") (SYMBOL "1")) (list (VARIABLE "V6") (SYMBOL "0")) (list (VARIABLE "V7") (SYMBOL "0")) (list (VARIABLE "V8") (SYMBOL "1")) (list (VARIABLE "V2") (LAMBDA)) (list (VARIABLE "V4") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V8") (SYMBOL "0") (VARIABLE "V5")) (list (VARIABLE "V5") (SYMBOL "1") (VARIABLE "V6")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V0")) (list (VARIABLE "V6") (SYMBOL "1") (VARIABLE "V2")) (list (VARIABLE "V4") (SYMBOL "1") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V4")) (list (VARIABLE "V3") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V5") (SYMBOL "1") (VARIABLE "V5")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V0")) (list (VARIABLE "V3") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V7") (SYMBOL "0") (VARIABLE "V7")) (list (VARIABLE "V5") (SYMBOL "0") (VARIABLE "V7"))) 'V0))
# Out:
# (pict '(prog #<procedure:...t/private/utils.rkt:1193:6> 494) 816 494 494 0 '() #f #f)

# %%
(define resposta9
    null
)

# %%
(automaton-correction ((compose nfa->dfa grammar->nfa) resposta9) ((compose nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3 V4 V5 V6 V7 V8) '(|0| |1|) (list (list (VARIABLE "V3") (SYMBOL "0") (VARIABLE "V8")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V7")) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V6")) (list (VARIABLE "V4") (SYMBOL "0") (VARIABLE "V5")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V4")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V3")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "1")) (list (VARIABLE "V1") (SYMBOL "1")) (list (VARIABLE "V2") (SYMBOL "1")) (list (VARIABLE "V3") (SYMBOL "1")) (list (VARIABLE "V4") (SYMBOL "1")) (list (VARIABLE "V5") (SYMBOL "1")) (list (VARIABLE "V6") (SYMBOL "0")) (list (VARIABLE "V7") (SYMBOL "0")) (list (VARIABLE "V8") (SYMBOL "1")) (list (VARIABLE "V2") (LAMBDA)) (list (VARIABLE "V4") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V8") (SYMBOL "0") (VARIABLE "V5")) (list (VARIABLE "V5") (SYMBOL "1") (VARIABLE "V6")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V0")) (list (VARIABLE "V6") (SYMBOL "1") (VARIABLE "V2")) (list (VARIABLE "V4") (SYMBOL "1") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V4")) (list (VARIABLE "V3") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V5") (SYMBOL "1") (VARIABLE "V5")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V0")) (list (VARIABLE "V3") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V7") (SYMBOL "0") (VARIABLE "V7")) (list (VARIABLE "V5") (SYMBOL "0") (VARIABLE "V7"))) 'V0)))

# %% [markdown]
# #### Questão 10

# %% [markdown]
# Crie uma gramática equivalente ao seguinte AFD:

# %%
((compose dfa->pict nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3 V4 V5 V6 V7 V8 V9 V10 V11) '(|0| |1|) (list (list (VARIABLE "V8") (SYMBOL "1") (VARIABLE "V11")) (list (VARIABLE "V9") (SYMBOL "0") (VARIABLE "V10")) (list (VARIABLE "V6") (SYMBOL "0") (VARIABLE "V9")) (list (VARIABLE "V6") (SYMBOL "0") (VARIABLE "V8")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V7")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V6")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V5")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V4")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V3")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "0")) (list (VARIABLE "V1") (SYMBOL "1")) (list (VARIABLE "V2") (SYMBOL "0")) (list (VARIABLE "V3") (SYMBOL "0")) (list (VARIABLE "V4") (SYMBOL "0")) (list (VARIABLE "V5") (SYMBOL "0")) (list (VARIABLE "V6") (SYMBOL "0")) (list (VARIABLE "V7") (SYMBOL "1")) (list (VARIABLE "V8") (SYMBOL "0")) (list (VARIABLE "V9") (SYMBOL "0")) (list (VARIABLE "V10") (SYMBOL "1")) (list (VARIABLE "V11") (SYMBOL "0")) (list (VARIABLE "V0") (LAMBDA)) (list (VARIABLE "V4") (LAMBDA)) (list (VARIABLE "V5") (LAMBDA)) (list (VARIABLE "V7") (SYMBOL "0") (VARIABLE "V6")) (list (VARIABLE "V7") (SYMBOL "1") (VARIABLE "V6")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V10") (SYMBOL "0") (VARIABLE "V7")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V11")) (list (VARIABLE "V5") (SYMBOL "1") (VARIABLE "V4")) (list (VARIABLE "V8") (SYMBOL "1") (VARIABLE "V9")) (list (VARIABLE "V4") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V2") (SYMBOL "1") (VARIABLE "V0")) (list (VARIABLE "V3") (SYMBOL "0") (VARIABLE "V6")) (list (VARIABLE "V2") (SYMBOL "1") (VARIABLE "V5")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V5")) (list (VARIABLE "V10") (SYMBOL "0") (VARIABLE "V0"))) 'V0))
# Out:
# (pict '(prog #<procedure:...t/private/utils.rkt:1193:6> 235) 816 235 235 0 '() #f #f)

# %%
(define resposta10
    null
)

# %%
(automaton-correction ((compose nfa->dfa grammar->nfa) resposta10) ((compose nfa->dfa grammar->nfa) (grammar '(V0 V1 V2 V3 V4 V5 V6 V7 V8 V9 V10 V11) '(|0| |1|) (list (list (VARIABLE "V8") (SYMBOL "1") (VARIABLE "V11")) (list (VARIABLE "V9") (SYMBOL "0") (VARIABLE "V10")) (list (VARIABLE "V6") (SYMBOL "0") (VARIABLE "V9")) (list (VARIABLE "V6") (SYMBOL "0") (VARIABLE "V8")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V7")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V6")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V5")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V4")) (list (VARIABLE "V1") (SYMBOL "1") (VARIABLE "V3")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V2")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V0") (SYMBOL "0")) (list (VARIABLE "V1") (SYMBOL "1")) (list (VARIABLE "V2") (SYMBOL "0")) (list (VARIABLE "V3") (SYMBOL "0")) (list (VARIABLE "V4") (SYMBOL "0")) (list (VARIABLE "V5") (SYMBOL "0")) (list (VARIABLE "V6") (SYMBOL "0")) (list (VARIABLE "V7") (SYMBOL "1")) (list (VARIABLE "V8") (SYMBOL "0")) (list (VARIABLE "V9") (SYMBOL "0")) (list (VARIABLE "V10") (SYMBOL "1")) (list (VARIABLE "V11") (SYMBOL "0")) (list (VARIABLE "V0") (LAMBDA)) (list (VARIABLE "V4") (LAMBDA)) (list (VARIABLE "V5") (LAMBDA)) (list (VARIABLE "V7") (SYMBOL "0") (VARIABLE "V6")) (list (VARIABLE "V7") (SYMBOL "1") (VARIABLE "V6")) (list (VARIABLE "V1") (SYMBOL "0") (VARIABLE "V1")) (list (VARIABLE "V2") (SYMBOL "0") (VARIABLE "V3")) (list (VARIABLE "V10") (SYMBOL "0") (VARIABLE "V7")) (list (VARIABLE "V0") (SYMBOL "1") (VARIABLE "V11")) (list (VARIABLE "V5") (SYMBOL "1") (VARIABLE "V4")) (list (VARIABLE "V8") (SYMBOL "1") (VARIABLE "V9")) (list (VARIABLE "V4") (SYMBOL "1") (VARIABLE "V1")) (list (VARIABLE "V2") (SYMBOL "1") (VARIABLE "V0")) (list (VARIABLE "V3") (SYMBOL "0") (VARIABLE "V6")) (list (VARIABLE "V2") (SYMBOL "1") (VARIABLE "V5")) (list (VARIABLE "V0") (SYMBOL "0") (VARIABLE "V5")) (list (VARIABLE "V10") (SYMBOL "0") (VARIABLE "V0"))) 'V0)))
